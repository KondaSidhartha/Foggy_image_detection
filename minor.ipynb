# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd model
# Out:
# /content/drive/MyDrive/model

# %%
# !pip install -qr requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00

# %%
import torch
import utils
display=utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.1/78.2 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.1 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/drive/MyDrive/model/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, 43.5ms
# image 2/2 /content/drive/MyDrive/model/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 1 cell phone, 70.9ms
# Speed: 0.6ms pre-process, 57.2ms inference, 136.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.0.1+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# !curl -L "https://app.roboflow.com/ds/y7TpU6UVab?key=ivoITNDxtU" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/IMG_6583-jpg_fog_jpg.rf.ca5c38cfe942e038a3a9d9f10aef1bf2.jpg
#  extracting: train/images/IMG_6584-jpg_fog_jpg.rf.32817628e97fa82602bb8f00884e4b05.jpg
#  extracting: train/images/IMG_6585-jpg_fog_jpg.rf.6b99af84ca1ecdbdd64f1fa713ec0bc2.jpg
#  extracting: train/images/IMG_6587-jpg_fog_jpg.rf.498b9a7581cda58e2a285c0af447c353.jpg
#  extracting: train/images/IMG_6590-jpg_fog_jpg.rf.c4e3fd3a3d496c1ad5b56725e3e2e7b1.jpg
#  extracting: train/images/IMG_6593-JPG_fog_jpg.rf.57a3d097cea363a56a8662759bfe3beb.jpg
#  extracting: train/images/IMG_6596-JPG_fog_jpg.rf.06804b5457a475b34a047387b5807eeb.jpg
#  extracting: train/images/IMG_6597-JPG_fog_jpg.rf.f0b4dd197997dea462b8822a8a71cf8a.jpg
#  extracting: train/images/IMG_6599-JPG_fog_jpg.rf.05aab0aec228d54204ad9226e1b009a4.jpg
#  extracting: train/images/IMG_6601-JPG_fog_jpg.rf.45629164321a483b4d06a818aff5e281.jpg
# ...

# %%
import os
os.environ["DATASET_DIRECTORY"]="/content/drive/MyDrive/datasets";

# %%
# !python train.py --img 416 --batch 16 --epochs 10 --data data.yaml --weights yolov5s.pt --cache
# Out:
# 2023-06-22 07:14:40.564315: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 07:14:41.555682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --hide-conf --hide-labels --line-thickness 1 --source test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1327 /content/drive/MyDrive/model/test/images/0-0-img_jpg.rf.9ce0a63e29d61d9c1d666261abe399da.jpg: 416x416 7 boats, 7.4ms
# image 2/1327 /content/drive/MyDrive/model/test/images/000000047203-jpg_fog_jpg.rf.35f48d70801e4e1dd3b8e3898d405789.jpg: 416x416 3 boats, 7.5ms
# ...
